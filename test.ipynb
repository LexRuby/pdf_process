# %% [markdown]
# # minerU test

# %%
from minerU_call import process_pdf
# Out:
# import tensorrt_llm failed, if do not use tensorrt, ignore this message
# import lmdeploy failed, if do not use lmdeploy, ignore this message

# %%
pdf_path = './data/gartner_官网/200604_Gartner_3 keys changing sales comp.pdf'
md_path,img_path = process_pdf(pdf_path)
# Out:
# 创建输出目录: output_200604_Gartner_3 keys changing sales comp
# 读取PDF文件: ./data/gartner_官网/200604_Gartner_3 keys changing sales comp.pdf
# 2024-12-24 17:29:06.565 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:57 - cid_count: 0, text_len: 16559, cid_chars_radio: 0.0
# 2024-12-24 17:29:06.601 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:78 - DocAnalysis init, this may take some times, layout_model: layoutlmv3, apply_formula: True, apply_ocr: False, apply_table: False, table_model: rapid_table, lang: None
# 2024-12-24 17:29:06.601 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:91 - using device: cuda
# 2024-12-24 17:29:06.602 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:95 - using models_dir: /mnt/shiyue/.cache/modelscope/hub/opendatalab/PDF-Extract-Kit-1___0/models
# 使用文本模式进行处理
# [12/24 17:29:06 detectron2]: Rank of current process: 0. World size: 1
# [12/24 17:29:06 detectron2]: Environment info:
# ...

# %%
pdf_path = './data/gartner_官网/202402 _Gartner_Business Alignment Tool.pdf'
md_path,img_path = process_pdf(pdf_path)
# Out:
# 创建输出目录: output_202402 _Gartner_Business Alignment Tool
# 读取PDF文件: ./data/gartner_官网/202402 _Gartner_Business Alignment Tool.pdf
# 2024-12-24 17:30:37.008 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:57 - cid_count: 0, text_len: 1835, cid_chars_radio: 0.0
# 2024-12-24 17:30:37.011 | WARNING  | magic_pdf.filter.pdf_classify_by_type:classify:334 - pdf is not classified by area and text_len, by_image_area: False, by_text: True, by_avg_words: True, by_img_num: True, by_text_layout: True, by_img_narrow_strips: True, by_invalid_chars: True
# 2024-12-24 17:30:37.030 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:78 - DocAnalysis init, this may take some times, layout_model: layoutlmv3, apply_formula: True, apply_ocr: True, apply_table: False, table_model: rapid_table, lang: None
# 2024-12-24 17:30:37.030 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:91 - using device: cuda
# ...
